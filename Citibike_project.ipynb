# %%
# Import dependencies
import pandas as pd

# %%
# Import our input dataset
citi_May21_df = pd.read_csv('Resources/JC-202105-citibike-tripdata.csv', index_col=0)
citi_May21_df
# Out:
#                  rideable_type           started_at             ended_at  \
# ride_id
# 74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
# ...                        ...                  ...                  ...
# 62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22  2021-05-31 12:52:29
# E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19  2021-05-31 16:59:21
# E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35  2021-05-17 23:13:37
# EC973614DCA179A2   docked_bike  2021-05-31 20:48:58  2021-05-31 21:16:02
# 3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43  2021-05-23 14:30:59
#
#                              start_station_name start_station_id  \
# ride_id
# 74A4206E7487CBC9  9 St HBLR - Jackson St & 8 St            HB305
# 58EEE2950FFE01CE  9 St HBLR - Jackson St & 8 St            HB305
# 1429D912C16EEE59  9 St HBLR - Jackson St & 8 St            HB305
# FE9C5B74167CBCCD  9 St HBLR - Jackson St & 8 St            HB305
# B88D37626F000BBA                       Union St            JC051
# ...                                         ...              ...
# 62FF3FEDAAD7FCB3              Clinton St & 7 St            HB303
# E742AEA7068E0E4A              Clinton St & 7 St            HB303
# E769F9EE96D6433A                    Astor Place            JC077
# EC973614DCA179A2              Clinton St & 7 St            HB303
# 3571180FE5C52CB1              Clinton St & 7 St            HB303
#
#                                end_station_name end_station_id  start_lat  \
# ride_id
# 74A4206E7487CBC9  9 St HBLR - Jackson St & 8 St          HB305  40.747907
# 58EEE2950FFE01CE  9 St HBLR - Jackson St & 8 St          HB305  40.747907
# 1429D912C16EEE59  9 St HBLR - Jackson St & 8 St          HB305  40.747907
# FE9C5B74167CBCCD                Grand St & 2 St          HB405  40.747907
# B88D37626F000BBA                     Newark Ave          JC032  40.718211
# ...                                         ...            ...        ...
# 62FF3FEDAAD7FCB3               7 St & Monroe St          HB304  40.745420
# E742AEA7068E0E4A              Clinton St & 7 St          HB303  40.745420
# E769F9EE96D6433A                    Astor Place          JC077  40.719282
# EC973614DCA179A2              Clinton St & 7 St          HB303  40.745420
# 3571180FE5C52CB1              Clinton St & 7 St          HB303  40.745420
#
#                   start_lng    end_lat    end_lng member_casual
# ride_id
# 74A4206E7487CBC9 -74.038411  40.747907 -74.038412        casual
# 58EEE2950FFE01CE -74.038411  40.747907 -74.038412        member
# 1429D912C16EEE59 -74.038411  40.747907 -74.038412        casual
# FE9C5B74167CBCCD -74.038411  40.739130 -74.036180        casual
# B88D37626F000BBA -74.083639  40.721525 -74.046305        casual
# ...                     ...        ...        ...           ...
# 62FF3FEDAAD7FCB3 -74.033320  40.746413 -74.037977        casual
# E742AEA7068E0E4A -74.033320  40.745420 -74.033320        casual
# E769F9EE96D6433A -74.071261  40.719282 -74.071262        casual
# EC973614DCA179A2 -74.033320  40.745420 -74.033320        casual
# 3571180FE5C52CB1 -74.033320  40.745420 -74.033320        casual
#
# [45043 rows x 12 columns]

# %%
### Explore data
start = citi_May21_df['start_station_name'].unique()
end = citi_May21_df['end_station_name'].unique()

# %%
start
# Out:
# array(['9 St HBLR - Jackson St & 8 St', 'Union St', 'Brunswick St',
#        'Heights Elevator', 'Bergen Ave', 'City Hall', 'Montgomery St',
#        'Monmouth and 6th', 'Jersey & 6th St', 'Dixon Mills', 'Dey St',
#        '8 St & Washington St', 'Newark Ave',
#        'Columbus Park - Clinton St & 9 St',
#        '2 St HBLR - 2 St & Marshall St', 'Grand St & 2 St',
#        'Glenwood Ave', 'Pershing Field', 'Madison St & 10 St',
#        'Bloomfield St & 15 St', 'Leonard Gordon Park', 'Lincoln Park',
#        'Grand St & 14 St', 'Hoboken Ave at Monmouth St', 'Newport Pkwy',
#        'Journal Square', 'Baldwin at Montgomery', '6 St & Grand St',
#        'Harborside', 'Marin Light Rail', 'Lafayette Park', 'Newport PATH',
#        '4 St & Grand St', '7 St & Monroe St',
#        'Hoboken Terminal - River St & Hudson Pl', 'JC Medical Center',
#        'Stevens - River Ter & 6 St', 'Jersey & 3rd', 'McGinley Square',
#        'Communipaw & Berry Lane', 'Oakland Ave', 'Adams St & 11 St',
#        'Madison St & 1 St', 'Christ Hospital', 'Hilltop',
#        'Church Sq Park - 5 St & Park Ave', 'Fairmount Ave',
#        '11 St & Washington St', 'Columbus Dr at Exchange Pl',
#        'Mama Johnson Field - 4 St & Jackson St', 'Warren St',
#        'Paulus Hook', 'Manila & 1st', 'Riverview Park', 'Washington St',
#        'Columbus Drive', '5 Corners Library', 'Grand St', 'Sip Ave',
#        'Brunswick & 6th', 'Van Vorst Park', 'Jackson Square',
#        'Hamilton Park', 'Grove St PATH',
#        'South Waterfront Walkway - Sinatra Dr & 1 St', 'Morris Canal',
#        'Southwest Park - Jackson St & Observer Hwy', 'Essex Light Rail',
#        'Liberty Light Rail', 'Clinton St & 7 St', 'Astor Place'],
#       dtype=object)

# %%
# Identify ending locations that were never starting locations
not_start = []
for loc in end:
    if loc not in start:
        not_start.append(loc)
    
not_start
# Out:
# ['NYCBS DEPOT - DELANCEY',
#  '8 Ave & W 52 St',
#  'North Moore St & Greenwich St',
#  'Clinton St & Joralemon St',
#  '6 Ave & Canal St',
#  'Barrow St & Hudson St',
#  '8 Ave & W 38 St',
#  '9 Ave & W 18 St',
#  'W 13 St & 5 Ave',
#  'W 46 St & 11 Ave',
#  '11 Ave & W 59 St',
#  'Harrison St & Hudson St',
#  'West St & Liberty St',
#  'John St & William St',
#  'Vesey Pl & River Terrace',
#  nan,
#  'JCBS Depot',
#  'E 161 St & River Ave',
#  'Cabrini Blvd & W 177 St',
#  'Pier 40 Dock Station',
#  'Reade St & Broadway',
#  'Centre St & Worth St',
#  'Central Ave & Flushing Ave',
#  'West St & Chambers St',
#  '6 Ave & W 33 St',
#  '12 Ave & W 40 St',
#  'Broadway & W 41 St',
#  'Little West St & 1 Pl']

# %%
# Identify any starting locations that were never ending locations
not_end = []
for loc in start:
    if loc not in end:
        not_end.append(loc)
    
not_end
# Out:
# []
