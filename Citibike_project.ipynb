# %%
################
## This file was the used as our initial exploratory/ idea exploration dataset.  
## This is not the dataset used for the final project.

# %%
# Import dependencies
import pandas as pd

# %%
# Import our input dataset
citi_May21_df = pd.read_csv('Resources/202105-citibike-tripdata.csv', index_col=0)
citi_May21_df
# Out:
# C:\Users\makew\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  rideable_type           started_at             ended_at  \
# ride_id
# E12103A91226099A   docked_bike  2021-05-06 17:25:01  2021-05-06 17:45:25
# 26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08  2021-05-13 13:07:37
# A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13  2021-05-16 08:45:47
# 43E79A45997B7390   docked_bike  2021-05-01 08:38:14  2021-05-01 08:54:27
# 8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31  2021-05-09 08:27:05
# ...                        ...                  ...                  ...
# 766BB4E17F05DBB4   docked_bike  2021-05-26 20:48:14  2021-05-26 21:02:01
# 3A74372C4A83AF31   docked_bike  2021-05-22 16:28:54  2021-05-22 16:43:55
# ...

# %%
### Explore data
start = citi_May21_df['start_station_name'].unique()
end = citi_May21_df['end_station_name'].unique()

# %%
start
# Out:
# array(['Broadway & W 60 St', 'Broadway & W 25 St', '46 Ave & 5 St', ...,
#        'Goulden Ave & Bedford Park Blvd W', 'Grand Concourse & E 192 St',
#        'Marion Ave & Mosholu Pkwy'], dtype=object)

# %%
# Identify ending locations that were never starting locations
not_start = []
for loc in end:
    if loc not in start:
        not_start.append(loc)
    
not_start
# Out:
# [nan,
#  'Hoboken Terminal - River St & Hudson Pl',
#  'Sip Ave',
#  'Heights Elevator',
#  '11 St & Washington St',
#  'Bloomfield St & 15 St',
#  'Newport PATH',
#  'Pier 40 Dock Station',
#  'Church Sq Park - 5 St & Park Ave',
#  'Paulus Hook',
#  'Forrest WH station',
#  'NYCBS DEPOT - DELANCEY',
#  'Van Vorst Park',
#  'South Waterfront Walkway - Sinatra Dr & 1 St',
#  'Pier 40 X2',
#  'Washington St',
#  'Liberty Light Rail',
#  'Grand St & 14 St',
#  'Grand St',
#  'Marin Light Rail',
#  'Morris Canal',
#  'Columbus Dr at Exchange Pl',
#  'Adams St & 11 St',
#  'Bergen Ave',
#  'Decatur Ave & Bedford Park Blvd',
#  '6 St & Grand St',
#  'Mama Johnson Field - 4 St & Jackson St',
#  'Grove St PATH',
#  'Madison St & 1 St',
#  'Riverview Park']

# %%
# Identify any starting locations that were never ending locations
not_end = []
for loc in start:
    if loc not in end:
        not_end.append(loc)
    
not_end
# Out:
# [nan]

# %%
citi_May21_df['rideable_type'].nunique()
# Out:
# 2

# %%
citi_May21_df['rideable_type'].value_counts()
# Out:
# docked_bike      2724017
# electric_bike        148
# Name: rideable_type, dtype: int64

# %%
# Import additional input dataset - May 2020 data
citi_May20_df = pd.read_csv('Resources/202005-citibike-tripdata.csv', index_col=0)
citi_May20_df
# Out:
# C:\Users\makew\anaconda3\envs\mlenv\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                              starttime                  stoptime  \
# tripduration
# 336           2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 853           2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 78            2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 1185          2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 272           2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
# ...                                ...                       ...
# 981           2020-05-31 23:59:19.0310  2020-06-01 00:15:40.5590
# 367           2020-05-31 23:59:36.2270  2020-06-01 00:05:43.6200
# 1798          2020-05-31 23:59:37.7250  2020-06-01 00:29:36.6800
# 718           2020-05-31 23:59:47.7090  2020-06-01 00:11:46.5210
# ...

# %%
# Import additional input dataset - May 2019 data
citi_May19_df = pd.read_csv('Resources/201905-citibike-tripdata.csv', index_col=0)
citi_May19_df
# Out:
# C:\Users\makew\anaconda3\envs\mlenv\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                              starttime                  stoptime  \
# tripduration
# 139           2019-05-01 00:00:01.9010  2019-05-01 00:02:21.5170
# 754           2019-05-01 00:00:03.0210  2019-05-01 00:12:37.6920
# 2308          2019-05-01 00:00:04.6270  2019-05-01 00:38:33.1710
# 143           2019-05-01 00:00:19.3340  2019-05-01 00:02:42.5200
# 138           2019-05-01 00:00:22.1840  2019-05-01 00:02:40.6480
# ...                                ...                       ...
# 304           2019-05-31 23:59:45.5760  2019-06-01 00:04:50.4620
# 324           2019-05-31 23:59:46.4650  2019-06-01 00:05:11.1630
# 1926          2019-05-31 23:59:51.5060  2019-06-01 00:31:58.3920
# 2047          2019-05-31 23:59:52.4170  2019-06-01 00:34:00.1970
# ...

# %%
# Import additional input dataset - May 2018 data
citi_May18_df = pd.read_csv('Resources/201805-citibike-tripdata.csv', index_col=0)
citi_May18_df
# Out:
# C:\Users\makew\anaconda3\envs\mlenv\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                              starttime                  stoptime  \
# tripduration
# 367           2018-05-01 05:06:16.5840  2018-05-01 05:12:23.9650
# 1313          2018-05-01 06:25:49.4250  2018-05-01 06:47:42.7120
# 1798          2018-05-01 06:40:26.4450  2018-05-01 07:10:25.1790
# 518           2018-05-01 07:06:02.9730  2018-05-01 07:14:41.0040
# 109           2018-05-01 07:26:32.3450  2018-05-01 07:28:21.5420
# ...                                ...                       ...
# 1604          2018-05-31 22:08:40.5020  2018-05-31 22:35:25.2080
# 1946          2018-05-31 22:14:50.6050  2018-05-31 22:47:16.7380
# 1931          2018-05-31 22:15:14.2790  2018-05-31 22:47:25.9680
# 664           2018-05-31 22:26:50.8410  2018-05-31 22:37:54.9780
# ...
