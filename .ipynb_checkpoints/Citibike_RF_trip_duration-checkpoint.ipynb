# %%
# Initial imports.
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Loading data
file_path = Path("Resources/allmay_cleaned.csv")
allmay_df = pd.read_csv(file_path)
allmay_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           538  2016-05-01 00:00:03  2016-05-01 00:09:02               536
# 1           224  2016-05-01 00:00:04  2016-05-01 00:03:49               361
# 2           328  2016-05-01 00:00:14  2016-05-01 00:05:43               301
# 3           753  2016-05-01 00:00:26  2016-05-01 00:13:00               492
# 4           511  2016-05-01 00:00:33  2016-05-01 00:09:05               445
#
#    start station latitude  start station longitude  end station id  \
# 0               40.741444               -73.975361             497
# 1               40.716059               -73.991908             340
# 2               40.722174               -73.983688             311
# 3               40.750200               -73.990931             228
# 4               40.727408               -73.981420             537
#
#    end station latitude  end station longitude  bikeid  usertype  birth year  \
# ...

# %%
allmay_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                     int64
# birth year                 float64
# gender                       int64
# dtype: object

# %%
#  Convert 'starttime' column to type datetime from object
allmay_df['starttime'] = pd.to_datetime(allmay_df['starttime'])

# %%
# Split 'starttime' column into 'year', 'month', 'day', hour' and 'minute' columns
allmay_df['year'] = allmay_df['starttime'].dt.year
allmay_df['month'] = allmay_df['starttime'].dt.month
allmay_df['day'] = allmay_df['starttime'].dt.day
allmay_df['hour'] = allmay_df['starttime'].dt.hour
allmay_df['minute'] = allmay_df['starttime'].dt.minute

# %%
# Drop the datetime columns
allmay_df.drop(columns=["starttime", "stoptime"], inplace=True)
allmay_df.head()
# Out:
#    tripduration  start station id  start station latitude  \
# 0           538               536               40.741444
# 1           224               361               40.716059
# 2           328               301               40.722174
# 3           753               492               40.750200
# 4           511               445               40.727408
#
#    start station longitude  end station id  end station latitude  \
# 0               -73.975361             497             40.737050
# 1               -73.991908             340             40.712690
# 2               -73.983688             311             40.717227
# 3               -73.990931             228             40.754601
# 4               -73.981420             537             40.740259
#
#    end station longitude  bikeid  usertype  birth year  gender  year  month  \
# 0             -73.990093   23097         1      1986.0       2  2016      5
# ...

# %%
# convert 'birth year' column to int from float
allmay_df['birth year'] = allmay_df['birth year'].astype(int)

# %%
allmay_df.head()
# Out:
#    tripduration  start station id  start station latitude  \
# 0           538               536               40.741444
# 1           224               361               40.716059
# 2           328               301               40.722174
# 3           753               492               40.750200
# 4           511               445               40.727408
#
#    start station longitude  end station id  end station latitude  \
# 0               -73.975361             497             40.737050
# 1               -73.991908             340             40.712690
# 2               -73.983688             311             40.717227
# 3               -73.990931             228             40.754601
# 4               -73.981420             537             40.740259
#
#    end station longitude  bikeid  usertype  birth year  gender  year  month  \
# 0             -73.990093   23097         1        1986       2  2016      5
# ...

# %%
#####################
## Machine learning for trip duration

# %%
# Remove trip duration target from features data
y = allmay_df['tripduration'].ravel()
X = allmay_df.drop(columns=["tripduration"])

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=20,random_state=42)

# Fitting the model
rf_model = rf_model.fit(X_train, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-86af4d65c6b3> in <module>
#       3
#       4 # Fitting the model
# ----> 5 rf_model = rf_model.fit(X_train, y_train)
#       6
#       7 # Evaluate the model
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     391                     verbose=self.verbose, class_weight=self.class_weight,
#     392                     n_samples_bootstrap=n_samples_bootstrap)
# --> 393                 for i, t in enumerate(trees))
#     394
#     395             # Collect newly grown trees
#
# ~\anaconda3\envs\mlenv\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
# ...

# %%
## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
import tensorflow as tf

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-598aa996caae> in <module>
#       3
#       4 # Train the model
# ----> 5 log_classifier.fit(X_train,y_train)
#       6
#       7 # Evaluate the model
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1414                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1415                       sample_weight=sample_weight)
# -> 1416             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1417
#    1418         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
# ...

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=10, activation="relu", input_dim=15))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 143805/143805 [==============================] - 104s 716us/step - loss: -15853.5283 - accuracy: 0.7318
# Epoch 2/50
# 143805/143805 [==============================] - 109s 755us/step - loss: -107615.3281 - accuracy: 0.7342
# Epoch 3/50
#  88015/143805 [=================>............] - ETA: 43s - loss: -244621.3125 - accuracy: 0.7347
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a0e6a9a5865d> in <module>
#       8
#       9 # Train the model
# ---> 10 fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
#      11
#      12 # Evaluate the model using the test data
#
# ...
